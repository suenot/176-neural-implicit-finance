# %% [markdown]
# # Neural Implicit Finance: Volatility Surface SIREN
# This notebook demonstrates fitting a continuous Implied Volatility (IV) surface using Sine-based Implicit Neural Representations.

# %%
import torch
from model import SirenNet
print('SIREN Engine Ready.')
